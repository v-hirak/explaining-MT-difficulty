# %% [markdown]
# # Language Selection

# %%
import pandas as pd
import scipy.stats as stats

# %%
lang_data = pd.read_csv('../data_collection/lang_data.csv')

# %%
# Filter out languages with empty "ttr" values
ttr_langs = lang_data[lang_data['ttr'].notna()]

# %%
ttr_langs.to_csv("ttr_langs.csv", index=False)

# %%
# Distribution of "script" values
ttr_langs["genus"].value_counts()
# Out:
# Slavic             7
# Romance            6
# Germanic           4
# Chinese            2
# Finnic             2
# Indic              2
# Turkic             2
# Greek              1
# Basque             1
# Semitic            1
# Ugric              1
# Malayo-Sumbawan    1
# Japanese           1
# Korean             1
# Iranian            1
# Vietic             1
# Name: genus, dtype: int64

# %%
# Range of "ttr" values
ttr_langs["ttr"].min(), ttr_langs["ttr"].max()
# Out:
# (0.1668725, 0.5807387500000001)

# %%
lang_data["ttr"].min(), lang_data["ttr"].max()
# Out:
# (0.1668725, 0.5807387500000001)

# %% [markdown]
# ## Comparison of TTR Values

# %%
ttr_langs = pd.read_csv("ttr_langs.csv")

# %%
ttr_langs
# Out:
#         lang iso_code wals_code script   variety  \
# 0   afr_Latn      afr       afr   Latn  afri1274
# 1   bul_Cyrl      bul       bul   Cyrl  bulg1262
# 2   cat_Latn      cat       ctl   Latn  stan1289
# 3   ces_Latn      ces       cze   Latn  czec1258
# 4   cmn_Hans      cmn       mnd   Hans  beij1234
# 5   cmn_Hant      cmn       mnd   Hant  taib1240
# 6   ekk_Latn      ekk       est   Latn  esto1258
# 7   ell_Grek      ell       grk   Grek  mode1248
# 8   eng_Latn      eng       eng   Latn  stan1293
# 9   eus_Latn      eus       bsq   Latn  basq1248
# 10  fin_Latn      fin       fin   Latn  finn1318
# 11  fra_Latn      fra       fre   Latn  stan1290
# 12  heb_Hebr      heb       heb   Hebr  hebr1245
# 13  hin_Deva      hin       hin   Deva  hind1269
# 14  hun_Latn      hun       hun   Latn  hung1274
# 15  ind_Latn      ind       ind   Latn  indo1316
# 16  ita_Latn      ita       ita   Latn  ital1282
# 17  jpn_Jpan      jpn       jpn   Jpan  nucl1643
# 18  kor_Hang      kor       kor   Hang  kore1280
# 19  nld_Latn      nld       dut   Latn  dutc1256
# 20  pes_Arab      pes       prs   Arab  west2369
# 21  pol_Latn      pol       pol   Latn  poli1260
# 22  por_Latn      por       por   Latn  braz1246
# 23  ron_Latn      ron       rom   Latn  roma1327
# 24  rus_Cyrl      rus       rus   Cyrl  russ1263
# 25  slk_Latn      slk       svk   Latn  slov1269
# 26  slv_Latn      slv       slo   Latn  slov1268
# 27  spa_Latn      spa       spa   Latn  amer1254
# 28  swe_Latn      swe       swe   Latn  swed1254
# 29  tur_Latn      tur       tur   Latn  nucl1301
# 30  uig_Arab      uig       uyg   Arab  uigh1240
# 31  ukr_Cyrl      ukr       ukr   Cyrl  ukra1253
# 32  urd_Arab      urd       urd   Arab  urdu1245
# 33  vie_Latn      vie       vie   Latn  viet1252
#
#                                    name          family            genus  \
# 0                             Afrikaans   Indo-European         Germanic
# 1                             Bulgarian   Indo-European           Slavic
# 2                               Catalan   Indo-European          Romance
# 3                                 Czech   Indo-European           Slavic
# 4   Mandarin Chinese (Standard Beijing)    Sino-Tibetan          Chinese
# 5          Mandarin Chinese (Taiwanese)    Sino-Tibetan          Chinese
# 6                              Estonian          Uralic           Finnic
# 7                                 Greek   Indo-European            Greek
# 8                               English   Indo-European         Germanic
# 9                                Basque          Basque           Basque
# 10                              Finnish          Uralic           Finnic
# 11                               French   Indo-European          Romance
# 12                               Hebrew    Afro-Asiatic          Semitic
# 13                                Hindi   Indo-European            Indic
# 14                            Hungarian          Uralic            Ugric
# 15                           Indonesian    Austronesian  Malayo-Sumbawan
# 16                              Italian   Indo-European          Romance
# 17                             Japanese        Japanese         Japanese
# 18                               Korean          Korean           Korean
# 19                                Dutch   Indo-European         Germanic
# 20                      Western Persian   Indo-European          Iranian
# 21                               Polish   Indo-European           Slavic
# 22               Portuguese (Brazilian)   Indo-European          Romance
# 23                             Romanian   Indo-European          Romance
# 24                              Russian   Indo-European           Slavic
# 25                               Slovak   Indo-European           Slavic
# 26                            Slovenian   Indo-European           Slavic
# 27             Spanish (Latin American)   Indo-European          Romance
# 28                              Swedish   Indo-European         Germanic
# 29                              Turkish          Altaic           Turkic
# 30                               Uyghur          Altaic           Turkic
# 31                            Ukrainian   Indo-European           Slavic
# 32                                 Urdu   Indo-European            Indic
# 33                           Vietnamese  Austro-Asiatic           Vietic
#
#     d_syn  train_frac_estimate  ...         lh     lh_sd       is     is_sd  \
# 0    0.63             0.003780  ...   8.775156  0.020283   3.0000  0.000000
# 1    0.48             0.000000  ...   9.801146  0.025004   9.6000  0.489898
# 2    0.53             0.000000  ...   8.749058  0.027353   6.0000  0.000000
# 3    0.66             0.000000  ...  10.207946  0.027642  11.4000  0.519963
# 4    0.55             0.000000  ...  10.779490  0.023547   1.0000  0.000000
# 5    0.55             0.000000  ...  10.779490  0.023547   1.0000  0.000000
# 6    0.69             0.000000  ...  10.865350  0.034473   9.9300  0.406325
# 7    0.52             0.000000  ...   8.351142  0.021881   9.0000  0.000000
# 8    0.00             0.328954  ...   9.191172  0.025512   6.1375  0.236381
# 9    0.61             0.000000  ...   9.678490  0.023058  19.1300  1.411772
# 10   0.53             0.000000  ...  10.524684  0.034685  16.6450  0.394982
# 11   0.46             0.022465  ...   8.647570  0.028038   6.5000  0.000000
# 12   0.52             0.000000  ...   8.799549  0.026868  12.0000  0.000000
# 13   0.59             0.036833  ...   9.024243  0.030889  10.4800  0.499600
# 14   0.60             0.000000  ...  10.173391  0.026371   8.0000  0.000000
# 15   0.52             0.004078  ...  10.687845  0.029908   6.7000  0.458258
# 16   0.51             0.000000  ...   8.619638  0.026669   6.0000  0.000000
# 17   0.66             0.000000  ...   9.313048  0.026842   0.0000  0.000000
# 18   0.62             0.000000  ...  12.770966  0.021984   0.0000  0.000000
# 19   0.49             0.000000  ...   9.491824  0.025018   3.0000  0.000000
# 20   0.72             0.000000  ...   9.154790  0.028449   6.0000  0.000000
# 21   0.59             0.000000  ...  10.303766  0.022719  10.0000  0.000000
# 22   0.47             0.025189  ...   8.717850  0.024654   7.0000  0.000000
# 23   0.53             0.000000  ...   8.874969  0.028757   8.0500  0.150000
# 24   0.49             0.020363  ...  10.792712  0.024923  11.5000  0.000000
# 25   0.57             0.000000  ...  10.384103  0.027865  10.0000  0.000000
# 26   0.56             0.000000  ...   9.921261  0.026513   8.0000  0.000000
# 27   0.40             0.000209  ...   8.927430  0.026107   6.0000  0.000000
# 28   0.42             0.000000  ...   9.348340  0.027314   7.9400  1.100849
# 29   0.70             0.019187  ...  10.013037  0.026461  13.0000  0.000000
# 30   0.75             0.002206  ...   9.394497  0.018709  12.0000  0.000000
# 31   0.51             0.000000  ...  10.810925  0.026920   8.8900  0.312890
# 32   0.67             0.011426  ...   9.117101  0.025167  10.2100  0.407308
# 33   0.57             0.000000  ...   9.960264  0.024122   0.0000  0.000000
#
#          mfh    mfh_sd       -ia  -ia_sd  h_dep_avg  h_codep_avg
# 0   3.867342  0.550169 -0.667044     0.0   0.562348     0.462374
# 1   3.755937  0.593355 -0.349068     0.0   0.474122     0.681034
# 2   3.552882  0.336858 -0.517017     0.0   0.391360     0.624815
# 3   3.953692  0.776319 -0.327369     0.0   0.567528     0.872996
# 4   2.741360  0.148256 -0.998999     0.0        NaN          NaN
# 5   2.741360  0.148256 -0.998999     0.0        NaN          NaN
# 6   3.704048  0.648834 -0.177009     0.0        NaN          NaN
# 7   3.668588  0.509442 -0.347045     0.0   0.415117     0.675441
# 8   3.724105  0.361524 -0.670247     0.0   0.361244     0.384444
# 9   3.768162  0.776920 -0.317018     0.0   0.652487     0.874256
# 10  3.784225  0.768351 -0.185503     0.0   0.558933     0.686842
# 11  3.347726  0.268861 -0.555493     0.0   0.403985     0.497266
# 12  3.582897  0.498772 -0.439026     0.0   0.358503     0.618874
# 13  3.386435  0.341967 -0.676970     0.0   0.162412     0.497565
# 14  3.725090  0.655311 -0.397973     0.0   0.426837     0.794512
# 15  2.711113  0.303642 -0.803004     0.0   0.323759     0.499035
# 16  3.492087  0.306996 -0.545694     0.0   0.468257     0.643150
# 17  1.342381  1.342407 -0.915994     0.0   0.000000     0.468842
# 18  1.218765  1.218796 -0.803272     0.0   0.084429     0.232510
# 19  3.466606  0.233416 -0.599000     0.0   0.522466     0.653656
# 20  2.883289  0.021238 -0.691032     0.0        NaN          NaN
# 21  3.978716  0.826411 -0.287506     0.0   0.549506     0.837512
# 22  3.346369  0.244185 -0.512995     0.0   0.467104     0.534384
# 23  3.883758  0.670278 -0.303011     0.0   0.465315     0.580213
# 24  3.597493  0.583734 -0.286516     0.0   0.514020     0.787733
# 25  3.981665  0.721976 -0.304041     0.0   0.561982     0.802681
# 26  3.938217  0.625169 -0.284021     0.0   0.457278     0.828523
# 27  3.523571  0.372520 -0.514518     0.0   0.452387     0.592417
# 28  3.660457  0.372595 -0.452025     0.0   0.424804     0.485542
# 29  3.585127  0.724451 -0.225015     0.0   0.244240     0.673054
# 30  3.382143  0.847851 -0.370994     0.0   0.128204     0.770323
# 31  3.857031  0.714239 -0.318993     0.0   0.485001     0.790692
# 32  3.329645  0.254597 -0.737009     0.0   0.223812     0.509824
# 33  1.250804  1.227632 -1.000000     0.0   0.508399     0.653526
#
# [34 rows x 41 columns]

# %%
# Check for normality of "ttr" values
stats.shapiro(ttr_langs["ttr_flores"])
# Out:
# ShapiroResult(statistic=0.8109769225120544, pvalue=4.208420796203427e-05)

# %%
# Perform paired t-test on "ttr" and "ttr_flores" values
stats.ttest_rel(ttr_langs["ttr"], ttr_langs["ttr_flores"])
# Out:
# TtestResult(statistic=-2.6770029009751846, pvalue=0.011480873608365276, df=33)
